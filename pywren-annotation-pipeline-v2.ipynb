# %% [markdown]
# # Initial requirements
#
# This notebook requires IBM Cloud Object Storage and IBM Cloud Functions
# Please follow IBM Cloud dashboard and create both services.

# %% [markdown]
# ### IBM COS Setup
#
# Copy the file `config.json.template` to `config.json` and fill in the missing values for API keys, buckets and endpoints per these instructions:
#
# Setup a bucket in IBM Cloud Object Storage
#
# You need an IBM COS bucket which you will use to store the input data. If you don't know of any of your existing buckets or would like like to create a new one, please navigate to your cloud resource list, then find and select your storage instance. From here, you will be able to view all your buckets and can create a new bucket in the region you prefer. Make sure you copy the correct endpoint for the bucket from the Endpoint tab of this COS service dashboard. Note: The bucket names must be unique.
#
# Obtain the API key and endpoint to the IBM Cloud Functions service. Navigate to Getting Started > API Key from the side menu and copy the values for "Current Namespace", "Host" and "Key" into the config below. Make sure to add "https://" to the host when adding it as the endpoint.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# These are Python and Python lib path we want to use
import sys
sys.executable, sys.prefix
# Out:
# ('/opt/dev/miniconda3/envs/pywren-ibm/bin/python',
#  '/opt/dev/miniconda3/envs/pywren-ibm')

# %%
#Install PyWren-IBM if needed
try:
    import pywren_ibm_cloud as pywren
except ModuleNotFoundError:    
    # !{sys.executable} -m pip install -U pywren-ibm-cloud==1.0.10
    import pywren_ibm_cloud as pywren

pywren.__version__
# Out:
# '1.0.10'

# %%
# We need this to overcome Python notebooks limitations of too many open files
import resource
soft, hard = resource.getrlimit(resource.RLIMIT_NOFILE)
print('Bebore:', soft, hard)

# Raising the soft limit. Hard limits can be raised only by sudo users
resource.setrlimit(resource.RLIMIT_NOFILE, (hard, hard))
soft, hard = resource.getrlimit(resource.RLIMIT_NOFILE)
print('After:', soft, hard)
# Out:
# Bebore: 1024 4096
# After: 4096 4096

# %%
# %config Completer.use_jedi = False
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from matplotlib import pyplot as plt
from scipy.sparse import coo_matrix
from collections import defaultdict
from pyImagingMSpec.image_measures import isotope_image_correlation, isotope_pattern_match
from cpyImagingMSpec import measure_of_chaos
from itertools import chain
from pathlib import Path
import numpy as np
import pandas as pd
import pickle
import sys
import io

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
import json

config = json.load(open('config.json'))

# %% [markdown]
# ### Input Files Setup
#
# Copy the file `input_config.json.template` to `input_config.json` and fill in the missing values for buckets.

# %%
#input_config = json.load(open('metabolomics/input_config_small.json'))
input_config = json.load(open('metabolomics/input_config_big.json'))
# input_config = json.load(open('metabolomics/input_config_huge.json'))
input_data = input_config['dataset']
input_db = input_config['molecular_db']

# %%
input_data
# Out:
# {'bucket': 'pywren-annotation-pipeline',
#  'path': 'metabolomics/ds/AZ_Rat_brains',
#  'ds_segments': 'metabolomics/tmp/ds_segments',
#  'centr_segments': 'metabolomics/tmp/centr_segments',
#  'formula_images': 'metabolomics/tmp/formula_images'}

# %%
input_db
# Out:
# {'bucket': 'pywren-annotation-pipeline',
#  'formulas_chunks': 'metabolomics/db/formulas',
#  'centroids_pandas': 'metabolomics/db/centroids.pickle',
#  'databases': ['metabolomics/db/mol_db1.pickle'],
#  'adducts': ['', '+H', '+Na', '+K'],
#  'modifiers': ['', '-H2O', '-CO2', '-NH3']}

# %%
import ibm_boto3
from ibm_botocore.client import Config
from ibm_botocore.client import ClientError

# %%
cos_client = ibm_boto3.client(service_name='s3',
                              ibm_api_key_id=config['ibm_cos']['api_key'],
#                               ibm_auth_endpoint=config['ibm_cos']['auth_endpoint'],
                              config=Config(signature_version='oauth'),
                              endpoint_url=config['ibm_cos']['endpoint'])

# %% [markdown]
# # Upload test data into COS bucket

# %%
import os
from annotation_pipeline_v2.utils import upload_to_cos

# %%
for root, dirnames, filenames in os.walk(input_data['path']):
    for fn in filenames:
        f_path = f'{root}/{fn}'
        print(f_path)
        upload_to_cos(cos_client, f_path, input_config['dataset']['bucket'], f_path)
# Out:
# metabolomics/ds/AZ_Rat_brains/Image5.imzML
# Copying from metabolomics/ds/AZ_Rat_brains/Image5.imzML to pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/Image5.imzML
# Copy completed for pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/Image5.imzML
# metabolomics/ds/AZ_Rat_brains/Image5.ibd
# Copying from metabolomics/ds/AZ_Rat_brains/Image5.ibd to pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/Image5.ibd
# Copy completed for pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/Image5.ibd
# metabolomics/ds/AZ_Rat_brains/meta.json
# Copying from metabolomics/ds/AZ_Rat_brains/meta.json to pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/meta.json
# Copy completed for pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/meta.json
# metabolomics/ds/AZ_Rat_brains/config.json
# Copying from metabolomics/ds/AZ_Rat_brains/config.json to pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/config.json
# Copy completed for pywren-annotation-pipeline/metabolomics/ds/AZ_Rat_brains/config.json

# %% [markdown]
# # Generate Isotopic Peaks from Molecular Databases

# %%
from annotation_pipeline.molecular_db import dump_mol_db, build_database, \
    calculate_centroids, clean_formula_chunks

# %%
# Download commonly used mol DBs from METASPACE (add force=True to redownload if needed)
dump_mol_db(config, input_db['bucket'], 'metabolomics/db/mol_db1.pickle', 22) #HMDB-v4
dump_mol_db(config, input_db['bucket'], 'metabolomics/db/mol_db2.pickle', 19) #ChEBI-2018-01
dump_mol_db(config, input_db['bucket'], 'metabolomics/db/mol_db3.pickle', 24) #LipidMaps-2017-12-12
dump_mol_db(config, input_db['bucket'], 'metabolomics/db/mol_db4.pickle', 26) #SwissLipids-2018-02-02

# %%
#%%time
num_formulas, formula_chunk_keys = build_database(config, input_db)
# Out:
# 2019-05-07 19:22:55,871 [DEBUG] pywren_ibm_cloud.storage.backends.cos: Set IBM COS Endpoint to https://s3.eu-de.cloud-object-storage.appdomain.cloud
# 2019-05-07 19:22:55,872 [DEBUG] pywren_ibm_cloud.storage.backends.cos: Set IBM COS Auth Endpoint to https://iam.cloud.ibm.com/oidc/token
# 2019-05-07 19:22:55,873 [DEBUG] pywren_ibm_cloud.storage.backends.cos: IBM COS: Using api_key - Requesting new token
# 2019-05-07 19:22:56,126 [INFO] pywren_ibm_cloud.cf_connector: IBM Cloud Functions init for namespace: kovalev@embl.de_dev
# 2019-05-07 19:22:56,126 [INFO] pywren_ibm_cloud.cf_connector: IBM Cloud Functions init for host: https://eu-de.functions.cloud.ibm.com
# 2019-05-07 19:22:56,127 [DEBUG] pywren_ibm_cloud.cf_connector: CF user agent set to: python-requests/2.21.0 pywren-ibm-cloud
# 2019-05-07 19:22:56,128 [INFO] pywren_ibm_cloud.invokers: IBM Cloud Functions init for Runtime: ibmfunctions/pywren-metabolomics:3.6 - 2048MB
# 2019-05-07 19:22:56,128 [DEBUG] pywren_ibm_cloud.runtime.metadata: Downloading runtime pre-installed modules from COS
# 2019-05-07 19:22:56,206 [DEBUG] pywren_ibm_cloud.runtime.metadata: Verifying Python versions
# 2019-05-07 19:22:56,206 [INFO] pywren_ibm_cloud.executor: IBM Cloud Functions executor created with ID fad9eb55-eb1c
# 2019-05-07 19:22:56,207 [DEBUG] pywren_ibm_cloud.executor: Calling map on partitions from object storage flow
# 2019-05-07 19:22:56,209 [DEBUG] pywren_ibm_cloud.storage.backends.cos: Set IBM COS Endpoint to https://s3.eu-de.cloud-object-storage.appdomain.cloud
# 2019-05-07 19:22:56,209 [DEBUG] pywren_ibm_cloud.storage.backends.cos: Set IBM COS Auth Endpoint to https://iam.cloud.ibm.com/oidc/token
# 2019-05-07 19:22:56,210 [DEBUG] pywren_ibm_cloud.storage.backends.cos: IBM COS: Using api_key - Using token
# 2019-05-07 19:22:56,218 [DEBUG] pywren_ibm_cloud.partitioner: Starting partitioner
# 2019-05-07 19:22:56,674 [DEBUG] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Serializing function and data
# 2019-05-07 19:22:58,800 [DEBUG] pywren_ibm_cloud.serialize.serialize: Modules to transmit: {'/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ipykernel', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pexpect', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/prompt_toolkit', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyparsing.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyMSpec', 'annotation_pipeline', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pickleshare.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jupyter_core', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/parso', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jupyter_client', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/traitlets', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jedi', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/decorator.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/backcall', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyimzml', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyImagingMSpec', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ipython_genutils', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/wcwidth', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ptyprocess', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/cycler.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/IPython', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pygments'}
# 2019-05-07 19:22:58,801 [INFO] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Uploading function and data
# 2019-05-07 19:22:58,883 [DEBUG] pywren_ibm_cloud.storage.backends.cos: PUT Object pywren.jobs/fad9eb55-eb1c/261b0db7/aggdata.pickle - Size: 16.2KiB - OK
# 2019-05-07 19:23:00,851 [DEBUG] pywren_ibm_cloud.storage.backends.cos: PUT Object pywren.jobs/fad9eb55-eb1c/261b0db7/func.pickle - Size: 11.7MiB - OK
# 2019-05-07 19:23:00,852 [INFO] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Starting function invocation: generate_formulas() - Total: 84 activations
# 2019-05-07 19:23:00,986 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00002 - Activation ID: e5ba8188537f425cba8188537f325c7f - Time: 0.125 seconds
# 2019-05-07 19:23:00,990 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00009 - Activation ID: a4020b9896434c6e820b989643bc6ec2 - Time: 0.114 seconds
# 2019-05-07 19:23:01,004 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00014 - Activation ID: 09aabc9eb0b848d9aabc9eb0b848d93d - Time: 0.116 seconds
# 2019-05-07 19:23:01,005 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00008 - Activation ID: 21e23fe7db7645e2a23fe7db76f5e2fa - Time: 0.131 seconds
# 2019-05-07 19:23:01,008 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00003 - Activation ID: 7a3db00e4ce549aebdb00e4ce569ae8c - Time: 0.145 seconds
# 2019-05-07 19:23:01,009 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00010 - Activation ID: 063e8418a3204a49be8418a320fa493a - Time: 0.131 seconds
# 2019-05-07 19:23:01,010 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00007 - Activation ID: e4e03ce80a684b1ba03ce80a685b1ba0 - Time: 0.138 seconds
# 2019-05-07 19:23:01,014 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00006 - Activation ID: 63286786700349afa86786700339af3a - Time: 0.145 seconds
# 2019-05-07 19:23:01,019 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00004 - Activation ID: 7ad8419fbcaf433e98419fbcaff33ec3 - Time: 0.154 seconds
# 2019-05-07 19:23:01,021 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00022 - Activation ID: 8d700774f8b14484b00774f8b1c48455 - Time: 0.111 seconds
# 2019-05-07 19:23:01,024 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00048 - Activation ID: 6dc7b9e9152c46e587b9e9152c16e52e - Time: 0.036 seconds
# 2019-05-07 19:23:01,026 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00018 - Activation ID: bd92207a15da405492207a15dab05425 - Time: 0.130 seconds
# 2019-05-07 19:23:01,027 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00011 - Activation ID: e47e232858b5488abe232858b5288a45 - Time: 0.147 seconds
# 2019-05-07 19:23:01,042 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00025 - Activation ID: 292bd91a19144fb7abd91a1914ffb708 - Time: 0.126 seconds
# 2019-05-07 19:23:01,043 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00027 - Activation ID: 9849b3243c09402189b3243c0930218e - Time: 0.120 seconds
# 2019-05-07 19:23:01,048 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00017 - Activation ID: 4872b1ee77a24843b2b1ee77a2f84307 - Time: 0.153 seconds
# 2019-05-07 19:23:01,049 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00051 - Activation ID: 953b54815a044581bb54815a04e58155 - Time: 0.047 seconds
# 2019-05-07 19:23:01,050 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00024 - Activation ID: dfa5c92fa4a74bf9a5c92fa4a72bf973 - Time: 0.133 seconds
# 2019-05-07 19:23:01,053 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00015 - Activation ID: 98bc6a87a4624213bc6a87a462d21397 - Time: 0.164 seconds
# 2019-05-07 19:23:01,054 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00037 - Activation ID: 0c76f5955bc64a3fb6f5955bc67a3f4e - Time: 0.102 seconds
# 2019-05-07 19:23:01,056 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00021 - Activation ID: 535d6df368744f099d6df36874cf095f - Time: 0.150 seconds
# 2019-05-07 19:23:01,062 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00052 - Activation ID: 7d2827219811427ca827219811f27ca9 - Time: 0.045 seconds
# 2019-05-07 19:23:01,066 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00016 - Activation ID: 559fc06345354d739fc06345351d73a0 - Time: 0.172 seconds
# 2019-05-07 19:23:01,068 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00031 - Activation ID: ffc585ac86b641a58585ac86b621a539 - Time: 0.131 seconds
# 2019-05-07 19:23:01,069 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00054 - Activation ID: 39b6e89a42a04b50b6e89a42a0db5045 - Time: 0.042 seconds
# 2019-05-07 19:23:01,072 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00035 - Activation ID: 50e021299f724f20a021299f729f20de - Time: 0.126 seconds
# 2019-05-07 19:23:01,075 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00005 - Activation ID: 923554b8ee5c43deb554b8ee5ce3de11 - Time: 0.206 seconds
# 2019-05-07 19:23:01,078 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00023 - Activation ID: 552926d0069a4812a926d0069a981258 - Time: 0.165 seconds
# 2019-05-07 19:23:01,080 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00001 - Activation ID: 38f52ee4cf1e46b9b52ee4cf1e46b958 - Time: 0.222 seconds
# 2019-05-07 19:23:01,084 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00057 - Activation ID: ed778e49eb3543c1b78e49eb3563c143 - Time: 0.043 seconds
# 2019-05-07 19:23:01,090 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00029 - Activation ID: 41a1610bab3147e6a1610bab3107e602 - Time: 0.154 seconds
# 2019-05-07 19:23:01,091 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00058 - Activation ID: f57b48df1db14f56bb48df1db17f5601 - Time: 0.047 seconds
# 2019-05-07 19:23:01,092 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00034 - Activation ID: 9d54ef1c5f7e479294ef1c5f7e4792ac - Time: 0.149 seconds
# 2019-05-07 19:23:01,094 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00055 - Activation ID: 51b290b55d084c58b290b55d084c58df - Time: 0.064 seconds
# 2019-05-07 19:23:01,095 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00012 - Activation ID: 29d64ad142de403b964ad142de303b6a - Time: 0.207 seconds
# 2019-05-07 19:23:01,103 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00038 - Activation ID: 72dc7f0758f742cb9c7f0758f712cbaa - Time: 0.148 seconds
# 2019-05-07 19:23:01,105 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00049 - Activation ID: 52ad8d1191534cd4ad8d1191537cd478 - Time: 0.107 seconds
# 2019-05-07 19:23:01,108 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00039 - Activation ID: ae29c289f22c4dd0a9c289f22cddd0c9 - Time: 0.145 seconds
# 2019-05-07 19:23:01,113 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00056 - Activation ID: 7b839d55fb064b05839d55fb067b0591 - Time: 0.079 seconds
# 2019-05-07 19:23:01,116 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00013 - Activation ID: 1fff682718cf4596bf682718cf55969f - Time: 0.223 seconds
# 2019-05-07 19:23:01,119 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00045 - Activation ID: 9793c89daccc458993c89daccc55899e - Time: 0.142 seconds
# 2019-05-07 19:23:01,124 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00041 - Activation ID: 01906158ffe74a9f906158ffe76a9f15 - Time: 0.143 seconds
# 2019-05-07 19:23:01,125 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00033 - Activation ID: d42a20147b964212aa20147b96321240 - Time: 0.172 seconds
# 2019-05-07 19:23:01,127 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00032 - Activation ID: 17d1ce3cd2a1490e91ce3cd2a1b90ed8 - Time: 0.186 seconds
# 2019-05-07 19:23:01,129 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00030 - Activation ID: 34906f6d54324278906f6d5432d278df - Time: 0.180 seconds
# 2019-05-07 19:23:01,129 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00050 - Activation ID: 61a8f27d403e478fa8f27d403ed78ff3 - Time: 0.132 seconds
# 2019-05-07 19:23:01,131 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00000 - Activation ID: b2da2748512944029a27485129540212 - Time: 0.270 seconds
# 2019-05-07 19:23:01,131 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00062 - Activation ID: 312470a787bd4bd8a470a787bd5bd8ea - Time: 0.056 seconds
# 2019-05-07 19:23:01,134 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00053 - Activation ID: e4fca389cc8b40adbca389cc8b00ad66 - Time: 0.107 seconds
# 2019-05-07 19:23:01,138 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00044 - Activation ID: 557bc03ce3d1424cbbc03ce3d1224c4a - Time: 0.163 seconds
# 2019-05-07 19:23:01,139 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00061 - Activation ID: dfa4cad923f14819a4cad923f1181915 - Time: 0.074 seconds
# 2019-05-07 19:23:01,140 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00036 - Activation ID: 08dcc4d254d141519cc4d254d13151f6 - Time: 0.186 seconds
# 2019-05-07 19:23:01,142 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00059 - Activation ID: e9a9326cd4074e82a9326cd4072e823d - Time: 0.090 seconds
# 2019-05-07 19:23:01,145 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00020 - Activation ID: 59856aa25cc74e47856aa25cc72e4747 - Time: 0.238 seconds
# 2019-05-07 19:23:01,146 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00019 - Activation ID: 91fb98c8f6b145c1bb98c8f6b145c14d - Time: 0.247 seconds
# 2019-05-07 19:23:01,147 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00040 - Activation ID: 34a0334e5bcc4ebba0334e5bccdebb8d - Time: 0.179 seconds
# 2019-05-07 19:23:01,154 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00060 - Activation ID: 87f15fd4daed4520b15fd4daed452089 - Time: 0.085 seconds
# 2019-05-07 19:23:01,155 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00064 - Activation ID: 51a746c866e843dba746c866e833dbdc - Time: 0.073 seconds
# 2019-05-07 19:23:01,156 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00047 - Activation ID: 5bb5b360588846b5b5b3605888a6b580 - Time: 0.170 seconds
# 2019-05-07 19:23:01,161 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00067 - Activation ID: 827be97e9e374db7bbe97e9e372db774 - Time: 0.055 seconds
# 2019-05-07 19:23:01,163 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00066 - Activation ID: de2abfd6c1114025aabfd6c1111025d3 - Time: 0.058 seconds
# 2019-05-07 19:23:01,173 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00042 - Activation ID: 0f447bc78e5f4b96847bc78e5f4b9619 - Time: 0.204 seconds
# 2019-05-07 19:23:01,180 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00069 - Activation ID: 6bdd389cdd7a41129d389cdd7ad11219 - Time: 0.057 seconds
# 2019-05-07 19:23:01,181 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00043 - Activation ID: d3a2da54172e4f67a2da54172e3f67da - Time: 0.208 seconds
# 2019-05-07 19:23:01,188 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00065 - Activation ID: c219655bfcb4483a99655bfcb4e83a95 - Time: 0.101 seconds
# 2019-05-07 19:23:01,189 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00063 - Activation ID: 3ab3f300ac4942c4b3f300ac4932c45b - Time: 0.112 seconds
# 2019-05-07 19:23:01,192 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00026 - Activation ID: dbd35a89dd614b85935a89dd619b850a - Time: 0.273 seconds
# 2019-05-07 19:23:01,196 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00046 - Activation ID: 9a642d9bf95846f6a42d9bf95866f6ca - Time: 0.217 seconds
# 2019-05-07 19:23:01,198 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00028 - Activation ID: 6b7fd52b7dc34c7abfd52b7dc3fc7a5b - Time: 0.274 seconds
# 2019-05-07 19:23:01,199 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00073 - Activation ID: 956b46a19e384516ab46a19e38b5169e - Time: 0.039 seconds
# 2019-05-07 19:23:01,201 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00072 - Activation ID: e1cacb244ea746808acb244ea7b680a5 - Time: 0.049 seconds
# 2019-05-07 19:23:01,203 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00070 - Activation ID: e58317d16558474c8317d16558974c38 - Time: 0.085 seconds
# 2019-05-07 19:23:01,214 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00074 - Activation ID: b809c28556f64db989c28556f6fdb97b - Time: 0.049 seconds
# 2019-05-07 19:23:01,224 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00076 - Activation ID: b06c98f5184e45bcac98f5184e15bce4 - Time: 0.054 seconds
# 2019-05-07 19:23:01,228 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00083 - Activation ID: 6ec1c873350a432781c873350a1327e3 - Time: 0.032 seconds
# 2019-05-07 19:23:01,231 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00075 - Activation ID: f083e6b6ff06463883e6b6ff0626386a - Time: 0.062 seconds
# 2019-05-07 19:23:01,233 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00078 - Activation ID: 4164f1375d4f4e54a4f1375d4fde545e - Time: 0.053 seconds
# 2019-05-07 19:23:01,236 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00077 - Activation ID: f47b9d92445e4515bb9d92445e15150c - Time: 0.063 seconds
# 2019-05-07 19:23:01,240 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00071 - Activation ID: 9aeae04efced4812aae04efced281285 - Time: 0.090 seconds
# 2019-05-07 19:23:01,246 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00068 - Activation ID: 42faa454c66a4ef8baa454c66adef8db - Time: 0.112 seconds
# 2019-05-07 19:23:01,261 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00080 - Activation ID: 836f4e98d8f04cddaf4e98d8f05cdde5 - Time: 0.076 seconds
# 2019-05-07 19:23:01,266 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00079 - Activation ID: 2d8fda48a28f48ed8fda48a28f28edf3 - Time: 0.088 seconds
# 2019-05-07 19:23:01,275 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00082 - Activation ID: 0c8894ab1e69408d8894ab1e69b08dfc - Time: 0.084 seconds
# 2019-05-07 19:23:01,309 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00081 - Activation ID: 33ce696a7f214c0e8e696a7f210c0ed6 - Time: 0.122 seconds
# 2019-05-07 19:23:01,323 [DEBUG] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Serializing function and data
# 2019-05-07 19:23:03,439 [DEBUG] pywren_ibm_cloud.serialize.serialize: Modules to transmit: {'/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ipykernel', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pexpect', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/prompt_toolkit', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyparsing.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyMSpec', 'annotation_pipeline', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pickleshare.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jupyter_core', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/parso', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jupyter_client', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/traitlets', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/jedi', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/decorator.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/backcall', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyimzml', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pyImagingMSpec', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ipython_genutils', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/wcwidth', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/ptyprocess', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/cycler.py', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/IPython', '/opt/dev/miniconda3/envs/pywren-ibm/lib/python3.6/site-packages/pygments'}
# 2019-05-07 19:23:03,440 [INFO] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Uploading function and data
# 2019-05-07 19:23:03,535 [DEBUG] pywren_ibm_cloud.storage.backends.cos: PUT Object pywren.jobs/fad9eb55-eb1c/90f8f513/aggdata.pickle - Size: 36.7KiB - OK
# 2019-05-07 19:23:04,580 [DEBUG] pywren_ibm_cloud.storage.backends.cos: PUT Object pywren.jobs/fad9eb55-eb1c/90f8f513/func.pickle - Size: 11.7MiB - OK
# 2019-05-07 19:23:04,581 [INFO] pywren_ibm_cloud.executor: Executor ID fad9eb55-eb1c Starting function invocation: store_formulas() - Total: 1 activations
# 2019-05-07 19:23:04,622 [DEBUG] pywren_ibm_cloud.cf_connector: Executor ID fad9eb55-eb1c Function 00000 - Activation ID: 9cbd25fcaa654e03bd25fcaa655e03b7 - Time: 0.038 seconds
# 2019-05-07 19:23:04,624 [INFO] pywren_ibm_cloud.wren: Executor ID fad9eb55-eb1c Getting results...
# 2019-05-07 19:23:29,646 [DEBUG] pywren_ibm_cloud.future: Executor ID fad9eb55-eb1c Response from Function 00000 - Activation ID: 9cbd25fcaa654e03bd25fcaa655e03b7 - Time: 24.42 seconds
# 2019-05-07 19:23:29,665 [DEBUG] pywren_ibm_cloud.future: Executor ID fad9eb55-eb1c Got output from Function 00000 - Activation ID: 9cbd25fcaa654e03bd25fcaa655e03b7
# 2019-05-07 19:23:29,731 [INFO] pywren_ibm_cloud.wren: Executor ID fad9eb55-eb1c Finished getting results
# 2019-05-07 19:23:29,732 [INFO] pywren_ibm_cloud.wren: Executor ID fad9eb55-eb1c Cleaning partial results from cos://pywren-annotation-pipeline/pywren.jobs/fad9eb55-eb1c

# %%
num_formulas, len(formula_chunk_keys), formula_chunk_keys[:3]
# Out:
# (2406009,
#  256,
#  ['metabolomics/db/formulas/0.pickle',
#   'metabolomics/db/formulas/1.pickle',
#   'metabolomics/db/formulas/2.pickle'])

# %%
# %%time
centroids_shape, centroids_head = calculate_centroids(config, input_db, formula_chunk_keys)

# %%
centroids_shape
# Out:
# (9624036, 3)

# %%
centroids_head
# Out:
#            peak_i          mz         int
# formula_i
# 0               0  186.865300  100.000000
# 0               1  187.871573    0.057511
# 0               2  188.864972   92.851404
# 0               3  189.871182    0.053439
# 1               0  202.860214  100.000000
# 1               1  203.865913    0.070423
# 1               2  204.859832   92.940336
# 1               3  206.864036    0.190792

# %%
# Download centroids.pickle to local machine
resp = cos_client.get_object(Bucket=input_db['bucket'], Key=input_db['centroids_pandas'])
with open(input_db['centroids_pandas'], 'wb') as f:
    f.write(resp['Body'].read())

# %%
clean_formula_chunks(config, input_db, formula_chunk_keys)

# %% [markdown]
# # Run Annotation Pipeline

# %%
from annotation_pipeline_v2.pipeline import Pipeline

# %%
pipeline = Pipeline(input_config)

# %%
# %time pipeline.load_ds()
# Out:
# INFO:annotation-pipeline:Parsed imzml: 32224 spectra found
# CPU times: user 3.86 s, sys: 20.1 ms, total: 3.88 s
# Wall time: 3.89 s

# %%
# %time pipeline.segment_ds()
# Out:
# INFO:annotation-pipeline:Defining dataset segment bounds
# INFO:annotation-pipeline:Generated 282 dataset segments: [79.99772644 86.09687805]...[494.32427979 499.97991943]
# INFO:annotation-pipeline:Segmenting dataset into 282 segments
# DEBUG:annotation-pipeline:Segmenting spectra chunk 0
# DEBUG:annotation-pipeline:Segmenting spectra chunk 1
# DEBUG:annotation-pipeline:Segmenting spectra chunk 2
# DEBUG:annotation-pipeline:Segmenting spectra chunk 3
# DEBUG:annotation-pipeline:Segmenting spectra chunk 4
# DEBUG:annotation-pipeline:Segmenting spectra chunk 5
# DEBUG:annotation-pipeline:Segmenting spectra chunk 6
# CPU times: user 21 s, sys: 2.47 s, total: 23.4 s
# Wall time: 23.5 s

# %%
# %time pipeline.segment_centroids()
# Out:
# INFO:annotation-pipeline:Prepared 3695968 centroids
# INFO:annotation-pipeline:Segmenting centroids into 369 segments
# CPU times: user 6.33 s, sys: 895 ms, total: 7.23 s
# Wall time: 7.23 s

# %%
# %time formula_metrics_df = pipeline.annotate()
# Out:
# INFO:annotation-pipeline:Annotating...
# DEBUG:annotation-pipeline:Reading centroids segment 0 from metabolomics/tmp/centr_segments/centr_segm_0000.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 0-6
# DEBUG:annotation-pipeline:Saving 21 images
# DEBUG:annotation-pipeline:Segment 0 finished
# DEBUG:annotation-pipeline:Reading centroids segment 1 from metabolomics/tmp/centr_segments/centr_segm_0001.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 3-10
# DEBUG:annotation-pipeline:Saving 69 images
# DEBUG:annotation-pipeline:Segment 1 finished
# DEBUG:annotation-pipeline:Reading centroids segment 2 from metabolomics/tmp/centr_segments/centr_segm_0002.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 8-12
# DEBUG:annotation-pipeline:Saving 52 images
# DEBUG:annotation-pipeline:Segment 2 finished
# DEBUG:annotation-pipeline:Reading centroids segment 3 from metabolomics/tmp/centr_segments/centr_segm_0003.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 11-15
# DEBUG:annotation-pipeline:Saving 78 images
# DEBUG:annotation-pipeline:Segment 3 finished
# DEBUG:annotation-pipeline:Reading centroids segment 4 from metabolomics/tmp/centr_segments/centr_segm_0004.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 13-18
# DEBUG:annotation-pipeline:Saving 125 images
# DEBUG:annotation-pipeline:Segment 4 finished
# DEBUG:annotation-pipeline:Reading centroids segment 5 from metabolomics/tmp/centr_segments/centr_segm_0005.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 16-20
# DEBUG:annotation-pipeline:Saving 100 images
# DEBUG:annotation-pipeline:Segment 5 finished
# DEBUG:annotation-pipeline:Reading centroids segment 6 from metabolomics/tmp/centr_segments/centr_segm_0006.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 18-22
# DEBUG:annotation-pipeline:Saving 96 images
# DEBUG:annotation-pipeline:Segment 6 finished
# DEBUG:annotation-pipeline:Reading centroids segment 7 from metabolomics/tmp/centr_segments/centr_segm_0007.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 19-25
# DEBUG:annotation-pipeline:Saving 134 images
# DEBUG:annotation-pipeline:Segment 7 finished
# DEBUG:annotation-pipeline:Reading centroids segment 8 from metabolomics/tmp/centr_segments/centr_segm_0008.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 22-27
# DEBUG:annotation-pipeline:Saving 139 images
# DEBUG:annotation-pipeline:Segment 8 finished
# DEBUG:annotation-pipeline:Reading centroids segment 9 from metabolomics/tmp/centr_segments/centr_segm_0009.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 24-30
# DEBUG:annotation-pipeline:Saving 115 images
# DEBUG:annotation-pipeline:Segment 9 finished
# DEBUG:annotation-pipeline:Reading centroids segment 10 from metabolomics/tmp/centr_segments/centr_segm_0010.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 26-32
# DEBUG:annotation-pipeline:Saving 151 images
# DEBUG:annotation-pipeline:Segment 10 finished
# DEBUG:annotation-pipeline:Reading centroids segment 11 from metabolomics/tmp/centr_segments/centr_segm_0011.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 28-34
# DEBUG:annotation-pipeline:Saving 133 images
# DEBUG:annotation-pipeline:Segment 11 finished
# DEBUG:annotation-pipeline:Reading centroids segment 12 from metabolomics/tmp/centr_segments/centr_segm_0012.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 30-36
# DEBUG:annotation-pipeline:Saving 186 images
# DEBUG:annotation-pipeline:Segment 12 finished
# DEBUG:annotation-pipeline:Reading centroids segment 13 from metabolomics/tmp/centr_segments/centr_segm_0013.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 32-39
# DEBUG:annotation-pipeline:Saving 187 images
# DEBUG:annotation-pipeline:Segment 13 finished
# DEBUG:annotation-pipeline:Reading centroids segment 14 from metabolomics/tmp/centr_segments/centr_segm_0014.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 35-41
# DEBUG:annotation-pipeline:Saving 162 images
# DEBUG:annotation-pipeline:Segment 14 finished
# DEBUG:annotation-pipeline:Reading centroids segment 15 from metabolomics/tmp/centr_segments/centr_segm_0015.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 36-43
# DEBUG:annotation-pipeline:Saving 165 images
# DEBUG:annotation-pipeline:Segment 15 finished
# DEBUG:annotation-pipeline:Reading centroids segment 16 from metabolomics/tmp/centr_segments/centr_segm_0016.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 38-45
# DEBUG:annotation-pipeline:Saving 153 images
# DEBUG:annotation-pipeline:Segment 16 finished
# DEBUG:annotation-pipeline:Reading centroids segment 17 from metabolomics/tmp/centr_segments/centr_segm_0017.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 40-46
# DEBUG:annotation-pipeline:Saving 174 images
# DEBUG:annotation-pipeline:Segment 17 finished
# DEBUG:annotation-pipeline:Reading centroids segment 18 from metabolomics/tmp/centr_segments/centr_segm_0018.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 43-48
# DEBUG:annotation-pipeline:Saving 143 images
# DEBUG:annotation-pipeline:Segment 18 finished
# DEBUG:annotation-pipeline:Reading centroids segment 19 from metabolomics/tmp/centr_segments/centr_segm_0019.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 44-51
# DEBUG:annotation-pipeline:Saving 101 images
# DEBUG:annotation-pipeline:Segment 19 finished
# DEBUG:annotation-pipeline:Reading centroids segment 20 from metabolomics/tmp/centr_segments/centr_segm_0020.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 45-52
# DEBUG:annotation-pipeline:Saving 172 images
# DEBUG:annotation-pipeline:Segment 20 finished
# DEBUG:annotation-pipeline:Reading centroids segment 21 from metabolomics/tmp/centr_segments/centr_segm_0021.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 47-54
# DEBUG:annotation-pipeline:Saving 130 images
# DEBUG:annotation-pipeline:Segment 21 finished
# DEBUG:annotation-pipeline:Reading centroids segment 22 from metabolomics/tmp/centr_segments/centr_segm_0022.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 49-56
# DEBUG:annotation-pipeline:Saving 128 images
# DEBUG:annotation-pipeline:Segment 22 finished
# DEBUG:annotation-pipeline:Reading centroids segment 23 from metabolomics/tmp/centr_segments/centr_segm_0023.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 51-57
# DEBUG:annotation-pipeline:Saving 195 images
# DEBUG:annotation-pipeline:Segment 23 finished
# DEBUG:annotation-pipeline:Reading centroids segment 24 from metabolomics/tmp/centr_segments/centr_segm_0024.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 53-60
# DEBUG:annotation-pipeline:Saving 200 images
# DEBUG:annotation-pipeline:Segment 24 finished
# DEBUG:annotation-pipeline:Reading centroids segment 25 from metabolomics/tmp/centr_segments/centr_segm_0025.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 55-61
# DEBUG:annotation-pipeline:Saving 123 images
# DEBUG:annotation-pipeline:Segment 25 finished
# DEBUG:annotation-pipeline:Reading centroids segment 26 from metabolomics/tmp/centr_segments/centr_segm_0026.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 56-63
# DEBUG:annotation-pipeline:Saving 107 images
# DEBUG:annotation-pipeline:Segment 26 finished
# DEBUG:annotation-pipeline:Reading centroids segment 27 from metabolomics/tmp/centr_segments/centr_segm_0027.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 57-65
# DEBUG:annotation-pipeline:Saving 116 images
# DEBUG:annotation-pipeline:Segment 27 finished
# DEBUG:annotation-pipeline:Reading centroids segment 28 from metabolomics/tmp/centr_segments/centr_segm_0028.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 59-67
# DEBUG:annotation-pipeline:Saving 165 images
# DEBUG:annotation-pipeline:Segment 28 finished
# DEBUG:annotation-pipeline:Reading centroids segment 29 from metabolomics/tmp/centr_segments/centr_segm_0029.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 60-69
# DEBUG:annotation-pipeline:Saving 153 images
# DEBUG:annotation-pipeline:Segment 29 finished
# DEBUG:annotation-pipeline:Reading centroids segment 30 from metabolomics/tmp/centr_segments/centr_segm_0030.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 62-70
# DEBUG:annotation-pipeline:Saving 167 images
# DEBUG:annotation-pipeline:Segment 30 finished
# DEBUG:annotation-pipeline:Reading centroids segment 31 from metabolomics/tmp/centr_segments/centr_segm_0031.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 63-71
# DEBUG:annotation-pipeline:Saving 225 images
# DEBUG:annotation-pipeline:Segment 31 finished
# DEBUG:annotation-pipeline:Reading centroids segment 32 from metabolomics/tmp/centr_segments/centr_segm_0032.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 65-73
# DEBUG:annotation-pipeline:Saving 306 images
# DEBUG:annotation-pipeline:Segment 32 finished
# DEBUG:annotation-pipeline:Reading centroids segment 33 from metabolomics/tmp/centr_segments/centr_segm_0033.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 67-74
# DEBUG:annotation-pipeline:Saving 206 images
# DEBUG:annotation-pipeline:Segment 33 finished
# DEBUG:annotation-pipeline:Reading centroids segment 34 from metabolomics/tmp/centr_segments/centr_segm_0034.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 69-76
# DEBUG:annotation-pipeline:Saving 139 images
# DEBUG:annotation-pipeline:Segment 34 finished
# DEBUG:annotation-pipeline:Reading centroids segment 35 from metabolomics/tmp/centr_segments/centr_segm_0035.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 70-78
# DEBUG:annotation-pipeline:Saving 145 images
# DEBUG:annotation-pipeline:Segment 35 finished
# DEBUG:annotation-pipeline:Reading centroids segment 36 from metabolomics/tmp/centr_segments/centr_segm_0036.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 72-79
# DEBUG:annotation-pipeline:Saving 115 images
# DEBUG:annotation-pipeline:Segment 36 finished
# DEBUG:annotation-pipeline:Reading centroids segment 37 from metabolomics/tmp/centr_segments/centr_segm_0037.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 73-81
# DEBUG:annotation-pipeline:Saving 134 images
# DEBUG:annotation-pipeline:Segment 37 finished
# DEBUG:annotation-pipeline:Reading centroids segment 38 from metabolomics/tmp/centr_segments/centr_segm_0038.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 74-83
# DEBUG:annotation-pipeline:Saving 163 images
# DEBUG:annotation-pipeline:Segment 38 finished
# DEBUG:annotation-pipeline:Reading centroids segment 39 from metabolomics/tmp/centr_segments/centr_segm_0039.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 76-83
# DEBUG:annotation-pipeline:Saving 163 images
# DEBUG:annotation-pipeline:Segment 39 finished
# DEBUG:annotation-pipeline:Reading centroids segment 40 from metabolomics/tmp/centr_segments/centr_segm_0040.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 78-85
# DEBUG:annotation-pipeline:Saving 125 images
# DEBUG:annotation-pipeline:Segment 40 finished
# DEBUG:annotation-pipeline:Reading centroids segment 41 from metabolomics/tmp/centr_segments/centr_segm_0041.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 79-87
# DEBUG:annotation-pipeline:Saving 206 images
# DEBUG:annotation-pipeline:Segment 41 finished
# DEBUG:annotation-pipeline:Reading centroids segment 42 from metabolomics/tmp/centr_segments/centr_segm_0042.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 80-89
# DEBUG:annotation-pipeline:Saving 110 images
# DEBUG:annotation-pipeline:Segment 42 finished
# DEBUG:annotation-pipeline:Reading centroids segment 43 from metabolomics/tmp/centr_segments/centr_segm_0043.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 82-90
# DEBUG:annotation-pipeline:Saving 173 images
# DEBUG:annotation-pipeline:Segment 43 finished
# DEBUG:annotation-pipeline:Reading centroids segment 44 from metabolomics/tmp/centr_segments/centr_segm_0044.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 83-92
# DEBUG:annotation-pipeline:Saving 153 images
# DEBUG:annotation-pipeline:Segment 44 finished
# DEBUG:annotation-pipeline:Reading centroids segment 45 from metabolomics/tmp/centr_segments/centr_segm_0045.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 85-93
# DEBUG:annotation-pipeline:Saving 146 images
# DEBUG:annotation-pipeline:Segment 45 finished
# DEBUG:annotation-pipeline:Reading centroids segment 46 from metabolomics/tmp/centr_segments/centr_segm_0046.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 86-95
# DEBUG:annotation-pipeline:Saving 156 images
# DEBUG:annotation-pipeline:Segment 46 finished
# DEBUG:annotation-pipeline:Reading centroids segment 47 from metabolomics/tmp/centr_segments/centr_segm_0047.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 88-95
# DEBUG:annotation-pipeline:Saving 206 images
# DEBUG:annotation-pipeline:Segment 47 finished
# DEBUG:annotation-pipeline:Reading centroids segment 48 from metabolomics/tmp/centr_segments/centr_segm_0048.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 89-97
# DEBUG:annotation-pipeline:Saving 237 images
# DEBUG:annotation-pipeline:Segment 48 finished
# DEBUG:annotation-pipeline:Reading centroids segment 49 from metabolomics/tmp/centr_segments/centr_segm_0049.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 91-98
# DEBUG:annotation-pipeline:Saving 113 images
# DEBUG:annotation-pipeline:Segment 49 finished
# DEBUG:annotation-pipeline:Reading centroids segment 50 from metabolomics/tmp/centr_segments/centr_segm_0050.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 92-99
# DEBUG:annotation-pipeline:Saving 228 images
# DEBUG:annotation-pipeline:Segment 50 finished
# DEBUG:annotation-pipeline:Reading centroids segment 51 from metabolomics/tmp/centr_segments/centr_segm_0051.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 94-101
# DEBUG:annotation-pipeline:Saving 182 images
# DEBUG:annotation-pipeline:Segment 51 finished
# DEBUG:annotation-pipeline:Reading centroids segment 52 from metabolomics/tmp/centr_segments/centr_segm_0052.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 95-102
# DEBUG:annotation-pipeline:Saving 119 images
# DEBUG:annotation-pipeline:Segment 52 finished
# DEBUG:annotation-pipeline:Reading centroids segment 53 from metabolomics/tmp/centr_segments/centr_segm_0053.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 96-104
# DEBUG:annotation-pipeline:Saving 175 images
# DEBUG:annotation-pipeline:Segment 53 finished
# DEBUG:annotation-pipeline:Reading centroids segment 54 from metabolomics/tmp/centr_segments/centr_segm_0054.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 97-105
# DEBUG:annotation-pipeline:Saving 112 images
# DEBUG:annotation-pipeline:Segment 54 finished
# DEBUG:annotation-pipeline:Reading centroids segment 55 from metabolomics/tmp/centr_segments/centr_segm_0055.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 98-106
# DEBUG:annotation-pipeline:Saving 86 images
# DEBUG:annotation-pipeline:Segment 55 finished
# DEBUG:annotation-pipeline:Reading centroids segment 56 from metabolomics/tmp/centr_segments/centr_segm_0056.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 99-107
# DEBUG:annotation-pipeline:Saving 231 images
# DEBUG:annotation-pipeline:Segment 56 finished
# DEBUG:annotation-pipeline:Reading centroids segment 57 from metabolomics/tmp/centr_segments/centr_segm_0057.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 101-109
# DEBUG:annotation-pipeline:Saving 132 images
# DEBUG:annotation-pipeline:Segment 57 finished
# DEBUG:annotation-pipeline:Reading centroids segment 58 from metabolomics/tmp/centr_segments/centr_segm_0058.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 102-110
# DEBUG:annotation-pipeline:Saving 126 images
# DEBUG:annotation-pipeline:Segment 58 finished
# DEBUG:annotation-pipeline:Reading centroids segment 59 from metabolomics/tmp/centr_segments/centr_segm_0059.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 103-111
# DEBUG:annotation-pipeline:Saving 203 images
# DEBUG:annotation-pipeline:Segment 59 finished
# DEBUG:annotation-pipeline:Reading centroids segment 60 from metabolomics/tmp/centr_segments/centr_segm_0060.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 104-112
# DEBUG:annotation-pipeline:Saving 291 images
# DEBUG:annotation-pipeline:Segment 60 finished
# DEBUG:annotation-pipeline:Reading centroids segment 61 from metabolomics/tmp/centr_segments/centr_segm_0061.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 106-115
# DEBUG:annotation-pipeline:Saving 112 images
# DEBUG:annotation-pipeline:Segment 61 finished
# DEBUG:annotation-pipeline:Reading centroids segment 62 from metabolomics/tmp/centr_segments/centr_segm_0062.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 107-115
# DEBUG:annotation-pipeline:Saving 375 images
# DEBUG:annotation-pipeline:Segment 62 finished
# DEBUG:annotation-pipeline:Reading centroids segment 63 from metabolomics/tmp/centr_segments/centr_segm_0063.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 109-117
# DEBUG:annotation-pipeline:Saving 139 images
# DEBUG:annotation-pipeline:Segment 63 finished
# DEBUG:annotation-pipeline:Reading centroids segment 64 from metabolomics/tmp/centr_segments/centr_segm_0064.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 109-117
# DEBUG:annotation-pipeline:Saving 208 images
# DEBUG:annotation-pipeline:Segment 64 finished
# DEBUG:annotation-pipeline:Reading centroids segment 65 from metabolomics/tmp/centr_segments/centr_segm_0065.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 110-119
# DEBUG:annotation-pipeline:Saving 120 images
# DEBUG:annotation-pipeline:Segment 65 finished
# DEBUG:annotation-pipeline:Reading centroids segment 66 from metabolomics/tmp/centr_segments/centr_segm_0066.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 111-120
# DEBUG:annotation-pipeline:Saving 146 images
# DEBUG:annotation-pipeline:Segment 66 finished
# DEBUG:annotation-pipeline:Reading centroids segment 67 from metabolomics/tmp/centr_segments/centr_segm_0067.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 113-121
# DEBUG:annotation-pipeline:Saving 137 images
# DEBUG:annotation-pipeline:Segment 67 finished
# DEBUG:annotation-pipeline:Reading centroids segment 68 from metabolomics/tmp/centr_segments/centr_segm_0068.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 115-122
# DEBUG:annotation-pipeline:Saving 140 images
# DEBUG:annotation-pipeline:Segment 68 finished
# DEBUG:annotation-pipeline:Reading centroids segment 69 from metabolomics/tmp/centr_segments/centr_segm_0069.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 115-123
# DEBUG:annotation-pipeline:Saving 114 images
# DEBUG:annotation-pipeline:Segment 69 finished
# DEBUG:annotation-pipeline:Reading centroids segment 70 from metabolomics/tmp/centr_segments/centr_segm_0070.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 117-124
# DEBUG:annotation-pipeline:Saving 109 images
# DEBUG:annotation-pipeline:Segment 70 finished
# DEBUG:annotation-pipeline:Reading centroids segment 71 from metabolomics/tmp/centr_segments/centr_segm_0071.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 117-125
# DEBUG:annotation-pipeline:Saving 207 images
# DEBUG:annotation-pipeline:Segment 71 finished
# DEBUG:annotation-pipeline:Reading centroids segment 72 from metabolomics/tmp/centr_segments/centr_segm_0072.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 119-126
# DEBUG:annotation-pipeline:Saving 207 images
# DEBUG:annotation-pipeline:Segment 72 finished
# DEBUG:annotation-pipeline:Reading centroids segment 73 from metabolomics/tmp/centr_segments/centr_segm_0073.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 120-127
# DEBUG:annotation-pipeline:Saving 196 images
# DEBUG:annotation-pipeline:Segment 73 finished
# DEBUG:annotation-pipeline:Reading centroids segment 74 from metabolomics/tmp/centr_segments/centr_segm_0074.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 121-129
# DEBUG:annotation-pipeline:Saving 150 images
# DEBUG:annotation-pipeline:Segment 74 finished
# DEBUG:annotation-pipeline:Reading centroids segment 75 from metabolomics/tmp/centr_segments/centr_segm_0075.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 122-131
# DEBUG:annotation-pipeline:Saving 104 images
# DEBUG:annotation-pipeline:Segment 75 finished
# DEBUG:annotation-pipeline:Reading centroids segment 76 from metabolomics/tmp/centr_segments/centr_segm_0076.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 123-132
# DEBUG:annotation-pipeline:Saving 299 images
# DEBUG:annotation-pipeline:Segment 76 finished
# DEBUG:annotation-pipeline:Reading centroids segment 77 from metabolomics/tmp/centr_segments/centr_segm_0077.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 124-133
# DEBUG:annotation-pipeline:Saving 102 images
# DEBUG:annotation-pipeline:Segment 77 finished
# DEBUG:annotation-pipeline:Reading centroids segment 78 from metabolomics/tmp/centr_segments/centr_segm_0078.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 125-134
# DEBUG:annotation-pipeline:Saving 190 images
# DEBUG:annotation-pipeline:Segment 78 finished
# DEBUG:annotation-pipeline:Reading centroids segment 79 from metabolomics/tmp/centr_segments/centr_segm_0079.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 126-135
# DEBUG:annotation-pipeline:Saving 125 images
# DEBUG:annotation-pipeline:Segment 79 finished
# DEBUG:annotation-pipeline:Reading centroids segment 80 from metabolomics/tmp/centr_segments/centr_segm_0080.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 127-136
# DEBUG:annotation-pipeline:Saving 139 images
# DEBUG:annotation-pipeline:Segment 80 finished
# DEBUG:annotation-pipeline:Reading centroids segment 81 from metabolomics/tmp/centr_segments/centr_segm_0081.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 129-137
# DEBUG:annotation-pipeline:Saving 232 images
# DEBUG:annotation-pipeline:Segment 81 finished
# DEBUG:annotation-pipeline:Reading centroids segment 82 from metabolomics/tmp/centr_segments/centr_segm_0082.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 130-137
# DEBUG:annotation-pipeline:Saving 142 images
# DEBUG:annotation-pipeline:Segment 82 finished
# DEBUG:annotation-pipeline:Reading centroids segment 83 from metabolomics/tmp/centr_segments/centr_segm_0083.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 131-138
# DEBUG:annotation-pipeline:Saving 124 images
# DEBUG:annotation-pipeline:Segment 83 finished
# DEBUG:annotation-pipeline:Reading centroids segment 84 from metabolomics/tmp/centr_segments/centr_segm_0084.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 132-139
# DEBUG:annotation-pipeline:Saving 185 images
# DEBUG:annotation-pipeline:Segment 84 finished
# DEBUG:annotation-pipeline:Reading centroids segment 85 from metabolomics/tmp/centr_segments/centr_segm_0085.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 133-140
# DEBUG:annotation-pipeline:Saving 138 images
# DEBUG:annotation-pipeline:Segment 85 finished
# DEBUG:annotation-pipeline:Reading centroids segment 86 from metabolomics/tmp/centr_segments/centr_segm_0086.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 134-140
# DEBUG:annotation-pipeline:Saving 232 images
# DEBUG:annotation-pipeline:Segment 86 finished
# DEBUG:annotation-pipeline:Reading centroids segment 87 from metabolomics/tmp/centr_segments/centr_segm_0087.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 135-142
# DEBUG:annotation-pipeline:Saving 107 images
# DEBUG:annotation-pipeline:Segment 87 finished
# DEBUG:annotation-pipeline:Reading centroids segment 88 from metabolomics/tmp/centr_segments/centr_segm_0088.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 136-143
# DEBUG:annotation-pipeline:Saving 169 images
# DEBUG:annotation-pipeline:Segment 88 finished
# DEBUG:annotation-pipeline:Reading centroids segment 89 from metabolomics/tmp/centr_segments/centr_segm_0089.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 137-144
# DEBUG:annotation-pipeline:Saving 105 images
# DEBUG:annotation-pipeline:Segment 89 finished
# DEBUG:annotation-pipeline:Reading centroids segment 90 from metabolomics/tmp/centr_segments/centr_segm_0090.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 137-144
# DEBUG:annotation-pipeline:Saving 202 images
# DEBUG:annotation-pipeline:Segment 90 finished
# DEBUG:annotation-pipeline:Reading centroids segment 91 from metabolomics/tmp/centr_segments/centr_segm_0091.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 138-146
# DEBUG:annotation-pipeline:Saving 62 images
# DEBUG:annotation-pipeline:Segment 91 finished
# DEBUG:annotation-pipeline:Reading centroids segment 92 from metabolomics/tmp/centr_segments/centr_segm_0092.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 139-146
# DEBUG:annotation-pipeline:Saving 113 images
# DEBUG:annotation-pipeline:Segment 92 finished
# DEBUG:annotation-pipeline:Reading centroids segment 93 from metabolomics/tmp/centr_segments/centr_segm_0093.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 140-148
# DEBUG:annotation-pipeline:Saving 72 images
# DEBUG:annotation-pipeline:Segment 93 finished
# DEBUG:annotation-pipeline:Reading centroids segment 94 from metabolomics/tmp/centr_segments/centr_segm_0094.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 140-148
# DEBUG:annotation-pipeline:Saving 110 images
# DEBUG:annotation-pipeline:Segment 94 finished
# DEBUG:annotation-pipeline:Reading centroids segment 95 from metabolomics/tmp/centr_segments/centr_segm_0095.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 142-150
# DEBUG:annotation-pipeline:Saving 88 images
# DEBUG:annotation-pipeline:Segment 95 finished
# DEBUG:annotation-pipeline:Reading centroids segment 96 from metabolomics/tmp/centr_segments/centr_segm_0096.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 143-151
# DEBUG:annotation-pipeline:Saving 154 images
# DEBUG:annotation-pipeline:Segment 96 finished
# DEBUG:annotation-pipeline:Reading centroids segment 97 from metabolomics/tmp/centr_segments/centr_segm_0097.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 144-152
# DEBUG:annotation-pipeline:Saving 112 images
# DEBUG:annotation-pipeline:Segment 97 finished
# DEBUG:annotation-pipeline:Reading centroids segment 98 from metabolomics/tmp/centr_segments/centr_segm_0098.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 144-152
# DEBUG:annotation-pipeline:Saving 126 images
# DEBUG:annotation-pipeline:Segment 98 finished
# DEBUG:annotation-pipeline:Reading centroids segment 99 from metabolomics/tmp/centr_segments/centr_segm_0099.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 145-153
# DEBUG:annotation-pipeline:Saving 52 images
# DEBUG:annotation-pipeline:Segment 99 finished
# DEBUG:annotation-pipeline:Reading centroids segment 100 from metabolomics/tmp/centr_segments/centr_segm_0100.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 146-154
# DEBUG:annotation-pipeline:Saving 155 images
# DEBUG:annotation-pipeline:Segment 100 finished
# DEBUG:annotation-pipeline:Reading centroids segment 101 from metabolomics/tmp/centr_segments/centr_segm_0101.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 147-155
# DEBUG:annotation-pipeline:Saving 151 images
# DEBUG:annotation-pipeline:Segment 101 finished
# DEBUG:annotation-pipeline:Reading centroids segment 102 from metabolomics/tmp/centr_segments/centr_segm_0102.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 148-156
# DEBUG:annotation-pipeline:Saving 141 images
# DEBUG:annotation-pipeline:Segment 102 finished
# DEBUG:annotation-pipeline:Reading centroids segment 103 from metabolomics/tmp/centr_segments/centr_segm_0103.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 148-157
# DEBUG:annotation-pipeline:Saving 236 images
# DEBUG:annotation-pipeline:Segment 103 finished
# DEBUG:annotation-pipeline:Reading centroids segment 104 from metabolomics/tmp/centr_segments/centr_segm_0104.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 150-159
# DEBUG:annotation-pipeline:Saving 105 images
# DEBUG:annotation-pipeline:Segment 104 finished
# DEBUG:annotation-pipeline:Reading centroids segment 105 from metabolomics/tmp/centr_segments/centr_segm_0105.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 151-160
# DEBUG:annotation-pipeline:Saving 287 images
# DEBUG:annotation-pipeline:Segment 105 finished
# DEBUG:annotation-pipeline:Reading centroids segment 106 from metabolomics/tmp/centr_segments/centr_segm_0106.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 152-161
# DEBUG:annotation-pipeline:Saving 156 images
# DEBUG:annotation-pipeline:Segment 106 finished
# DEBUG:annotation-pipeline:Reading centroids segment 107 from metabolomics/tmp/centr_segments/centr_segm_0107.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 153-162
# DEBUG:annotation-pipeline:Saving 202 images
# DEBUG:annotation-pipeline:Segment 107 finished
# DEBUG:annotation-pipeline:Reading centroids segment 108 from metabolomics/tmp/centr_segments/centr_segm_0108.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 154-162
# DEBUG:annotation-pipeline:Saving 58 images
# DEBUG:annotation-pipeline:Segment 108 finished
# DEBUG:annotation-pipeline:Reading centroids segment 109 from metabolomics/tmp/centr_segments/centr_segm_0109.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 155-163
# DEBUG:annotation-pipeline:Saving 175 images
# DEBUG:annotation-pipeline:Segment 109 finished
# DEBUG:annotation-pipeline:Reading centroids segment 110 from metabolomics/tmp/centr_segments/centr_segm_0110.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 155-164
# DEBUG:annotation-pipeline:Saving 117 images
# DEBUG:annotation-pipeline:Segment 110 finished
# DEBUG:annotation-pipeline:Reading centroids segment 111 from metabolomics/tmp/centr_segments/centr_segm_0111.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 156-165
# DEBUG:annotation-pipeline:Saving 93 images
# DEBUG:annotation-pipeline:Segment 111 finished
# DEBUG:annotation-pipeline:Reading centroids segment 112 from metabolomics/tmp/centr_segments/centr_segm_0112.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 157-166
# DEBUG:annotation-pipeline:Saving 175 images
# DEBUG:annotation-pipeline:Segment 112 finished
# DEBUG:annotation-pipeline:Reading centroids segment 113 from metabolomics/tmp/centr_segments/centr_segm_0113.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 159-167
# DEBUG:annotation-pipeline:Saving 91 images
# DEBUG:annotation-pipeline:Segment 113 finished
# DEBUG:annotation-pipeline:Reading centroids segment 114 from metabolomics/tmp/centr_segments/centr_segm_0114.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 160-168
# DEBUG:annotation-pipeline:Saving 131 images
# DEBUG:annotation-pipeline:Segment 114 finished
# DEBUG:annotation-pipeline:Reading centroids segment 115 from metabolomics/tmp/centr_segments/centr_segm_0115.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 161-169
# DEBUG:annotation-pipeline:Saving 77 images
# DEBUG:annotation-pipeline:Segment 115 finished
# DEBUG:annotation-pipeline:Reading centroids segment 116 from metabolomics/tmp/centr_segments/centr_segm_0116.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 162-169
# DEBUG:annotation-pipeline:Saving 165 images
# DEBUG:annotation-pipeline:Segment 116 finished
# DEBUG:annotation-pipeline:Reading centroids segment 117 from metabolomics/tmp/centr_segments/centr_segm_0117.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 162-169
# DEBUG:annotation-pipeline:Saving 57 images
# DEBUG:annotation-pipeline:Segment 117 finished
# DEBUG:annotation-pipeline:Reading centroids segment 118 from metabolomics/tmp/centr_segments/centr_segm_0118.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 163-171
# DEBUG:annotation-pipeline:Saving 152 images
# DEBUG:annotation-pipeline:Segment 118 finished
# DEBUG:annotation-pipeline:Reading centroids segment 119 from metabolomics/tmp/centr_segments/centr_segm_0119.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 164-171
# DEBUG:annotation-pipeline:Saving 202 images
# DEBUG:annotation-pipeline:Segment 119 finished
# DEBUG:annotation-pipeline:Reading centroids segment 120 from metabolomics/tmp/centr_segments/centr_segm_0120.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 165-172
# DEBUG:annotation-pipeline:Saving 116 images
# DEBUG:annotation-pipeline:Segment 120 finished
# DEBUG:annotation-pipeline:Reading centroids segment 121 from metabolomics/tmp/centr_segments/centr_segm_0121.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 166-173
# DEBUG:annotation-pipeline:Saving 192 images
# DEBUG:annotation-pipeline:Segment 121 finished
# DEBUG:annotation-pipeline:Reading centroids segment 122 from metabolomics/tmp/centr_segments/centr_segm_0122.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 167-174
# DEBUG:annotation-pipeline:Saving 103 images
# DEBUG:annotation-pipeline:Segment 122 finished
# DEBUG:annotation-pipeline:Reading centroids segment 123 from metabolomics/tmp/centr_segments/centr_segm_0123.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 167-175
# DEBUG:annotation-pipeline:Saving 37 images
# DEBUG:annotation-pipeline:Segment 123 finished
# DEBUG:annotation-pipeline:Reading centroids segment 124 from metabolomics/tmp/centr_segments/centr_segm_0124.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 168-175
# DEBUG:annotation-pipeline:Saving 114 images
# DEBUG:annotation-pipeline:Segment 124 finished
# DEBUG:annotation-pipeline:Reading centroids segment 125 from metabolomics/tmp/centr_segments/centr_segm_0125.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 169-177
# DEBUG:annotation-pipeline:Saving 73 images
# DEBUG:annotation-pipeline:Segment 125 finished
# DEBUG:annotation-pipeline:Reading centroids segment 126 from metabolomics/tmp/centr_segments/centr_segm_0126.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 169-178
# DEBUG:annotation-pipeline:Saving 139 images
# DEBUG:annotation-pipeline:Segment 126 finished
# DEBUG:annotation-pipeline:Reading centroids segment 127 from metabolomics/tmp/centr_segments/centr_segm_0127.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 171-179
# DEBUG:annotation-pipeline:Saving 78 images
# DEBUG:annotation-pipeline:Segment 127 finished
# DEBUG:annotation-pipeline:Reading centroids segment 128 from metabolomics/tmp/centr_segments/centr_segm_0128.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 171-179
# DEBUG:annotation-pipeline:Saving 106 images
# DEBUG:annotation-pipeline:Segment 128 finished
# DEBUG:annotation-pipeline:Reading centroids segment 129 from metabolomics/tmp/centr_segments/centr_segm_0129.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 172-180
# DEBUG:annotation-pipeline:Saving 69 images
# DEBUG:annotation-pipeline:Segment 129 finished
# DEBUG:annotation-pipeline:Reading centroids segment 130 from metabolomics/tmp/centr_segments/centr_segm_0130.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 172-181
# DEBUG:annotation-pipeline:Saving 130 images
# DEBUG:annotation-pipeline:Segment 130 finished
# DEBUG:annotation-pipeline:Reading centroids segment 131 from metabolomics/tmp/centr_segments/centr_segm_0131.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 173-182
# DEBUG:annotation-pipeline:Saving 223 images
# DEBUG:annotation-pipeline:Segment 131 finished
# DEBUG:annotation-pipeline:Reading centroids segment 132 from metabolomics/tmp/centr_segments/centr_segm_0132.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 175-184
# DEBUG:annotation-pipeline:Saving 105 images
# DEBUG:annotation-pipeline:Segment 132 finished
# DEBUG:annotation-pipeline:Reading centroids segment 133 from metabolomics/tmp/centr_segments/centr_segm_0133.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 175-184
# DEBUG:annotation-pipeline:Saving 232 images
# DEBUG:annotation-pipeline:Segment 133 finished
# DEBUG:annotation-pipeline:Reading centroids segment 134 from metabolomics/tmp/centr_segments/centr_segm_0134.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 177-184
# DEBUG:annotation-pipeline:Saving 36 images
# DEBUG:annotation-pipeline:Segment 134 finished
# DEBUG:annotation-pipeline:Reading centroids segment 135 from metabolomics/tmp/centr_segments/centr_segm_0135.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 177-186
# DEBUG:annotation-pipeline:Saving 96 images
# DEBUG:annotation-pipeline:Segment 135 finished
# DEBUG:annotation-pipeline:Reading centroids segment 136 from metabolomics/tmp/centr_segments/centr_segm_0136.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 178-186
# DEBUG:annotation-pipeline:Saving 260 images
# DEBUG:annotation-pipeline:Segment 136 finished
# DEBUG:annotation-pipeline:Reading centroids segment 137 from metabolomics/tmp/centr_segments/centr_segm_0137.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 179-187
# DEBUG:annotation-pipeline:Saving 119 images
# DEBUG:annotation-pipeline:Segment 137 finished
# DEBUG:annotation-pipeline:Reading centroids segment 138 from metabolomics/tmp/centr_segments/centr_segm_0138.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 180-187
# DEBUG:annotation-pipeline:Saving 210 images
# DEBUG:annotation-pipeline:Segment 138 finished
# DEBUG:annotation-pipeline:Reading centroids segment 139 from metabolomics/tmp/centr_segments/centr_segm_0139.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 181-188
# DEBUG:annotation-pipeline:Saving 15 images
# DEBUG:annotation-pipeline:Segment 139 finished
# DEBUG:annotation-pipeline:Reading centroids segment 140 from metabolomics/tmp/centr_segments/centr_segm_0140.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 181-189
# DEBUG:annotation-pipeline:Saving 63 images
# DEBUG:annotation-pipeline:Segment 140 finished
# DEBUG:annotation-pipeline:Reading centroids segment 141 from metabolomics/tmp/centr_segments/centr_segm_0141.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 182-189
# DEBUG:annotation-pipeline:Saving 237 images
# DEBUG:annotation-pipeline:Segment 141 finished
# DEBUG:annotation-pipeline:Reading centroids segment 142 from metabolomics/tmp/centr_segments/centr_segm_0142.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 184-191
# DEBUG:annotation-pipeline:Saving 99 images
# DEBUG:annotation-pipeline:Segment 142 finished
# DEBUG:annotation-pipeline:Reading centroids segment 143 from metabolomics/tmp/centr_segments/centr_segm_0143.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 184-191
# DEBUG:annotation-pipeline:Saving 153 images
# DEBUG:annotation-pipeline:Segment 143 finished
# DEBUG:annotation-pipeline:Reading centroids segment 144 from metabolomics/tmp/centr_segments/centr_segm_0144.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 185-191
# DEBUG:annotation-pipeline:Saving 18 images
# DEBUG:annotation-pipeline:Segment 144 finished
# DEBUG:annotation-pipeline:Reading centroids segment 145 from metabolomics/tmp/centr_segments/centr_segm_0145.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 186-192
# DEBUG:annotation-pipeline:Saving 55 images
# DEBUG:annotation-pipeline:Segment 145 finished
# DEBUG:annotation-pipeline:Reading centroids segment 146 from metabolomics/tmp/centr_segments/centr_segm_0146.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 186-193
# DEBUG:annotation-pipeline:Saving 207 images
# DEBUG:annotation-pipeline:Segment 146 finished
# DEBUG:annotation-pipeline:Reading centroids segment 147 from metabolomics/tmp/centr_segments/centr_segm_0147.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 187-194
# DEBUG:annotation-pipeline:Saving 42 images
# DEBUG:annotation-pipeline:Segment 147 finished
# DEBUG:annotation-pipeline:Reading centroids segment 148 from metabolomics/tmp/centr_segments/centr_segm_0148.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 188-194
# DEBUG:annotation-pipeline:Saving 81 images
# DEBUG:annotation-pipeline:Segment 148 finished
# DEBUG:annotation-pipeline:Reading centroids segment 149 from metabolomics/tmp/centr_segments/centr_segm_0149.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 188-195
# DEBUG:annotation-pipeline:Saving 72 images
# DEBUG:annotation-pipeline:Segment 149 finished
# DEBUG:annotation-pipeline:Reading centroids segment 150 from metabolomics/tmp/centr_segments/centr_segm_0150.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 189-197
# DEBUG:annotation-pipeline:Saving 62 images
# DEBUG:annotation-pipeline:Segment 150 finished
# DEBUG:annotation-pipeline:Reading centroids segment 151 from metabolomics/tmp/centr_segments/centr_segm_0151.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 189-197
# DEBUG:annotation-pipeline:Saving 210 images
# DEBUG:annotation-pipeline:Segment 151 finished
# DEBUG:annotation-pipeline:Reading centroids segment 152 from metabolomics/tmp/centr_segments/centr_segm_0152.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 191-199
# DEBUG:annotation-pipeline:Saving 53 images
# DEBUG:annotation-pipeline:Segment 152 finished
# DEBUG:annotation-pipeline:Reading centroids segment 153 from metabolomics/tmp/centr_segments/centr_segm_0153.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 191-199
# DEBUG:annotation-pipeline:Saving 8 images
# DEBUG:annotation-pipeline:Segment 153 finished
# DEBUG:annotation-pipeline:Reading centroids segment 154 from metabolomics/tmp/centr_segments/centr_segm_0154.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 191-200
# DEBUG:annotation-pipeline:Saving 162 images
# DEBUG:annotation-pipeline:Segment 154 finished
# DEBUG:annotation-pipeline:Reading centroids segment 155 from metabolomics/tmp/centr_segments/centr_segm_0155.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 192-201
# DEBUG:annotation-pipeline:Saving 100 images
# DEBUG:annotation-pipeline:Segment 155 finished
# DEBUG:annotation-pipeline:Reading centroids segment 156 from metabolomics/tmp/centr_segments/centr_segm_0156.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 193-202
# DEBUG:annotation-pipeline:Saving 168 images
# DEBUG:annotation-pipeline:Segment 156 finished
# DEBUG:annotation-pipeline:Reading centroids segment 157 from metabolomics/tmp/centr_segments/centr_segm_0157.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 194-202
# DEBUG:annotation-pipeline:Saving 9 images
# DEBUG:annotation-pipeline:Segment 157 finished
# DEBUG:annotation-pipeline:Reading centroids segment 158 from metabolomics/tmp/centr_segments/centr_segm_0158.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 194-203
# DEBUG:annotation-pipeline:Saving 137 images
# DEBUG:annotation-pipeline:Segment 158 finished
# DEBUG:annotation-pipeline:Reading centroids segment 159 from metabolomics/tmp/centr_segments/centr_segm_0159.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 195-203
# DEBUG:annotation-pipeline:Saving 253 images
# DEBUG:annotation-pipeline:Segment 159 finished
# DEBUG:annotation-pipeline:Reading centroids segment 160 from metabolomics/tmp/centr_segments/centr_segm_0160.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 197-205
# DEBUG:annotation-pipeline:Saving 114 images
# DEBUG:annotation-pipeline:Segment 160 finished
# DEBUG:annotation-pipeline:Reading centroids segment 161 from metabolomics/tmp/centr_segments/centr_segm_0161.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 197-205
# DEBUG:annotation-pipeline:Saving 115 images
# DEBUG:annotation-pipeline:Segment 161 finished
# DEBUG:annotation-pipeline:Reading centroids segment 162 from metabolomics/tmp/centr_segments/centr_segm_0162.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 198-205
# DEBUG:annotation-pipeline:Saving 113 images
# DEBUG:annotation-pipeline:Segment 162 finished
# DEBUG:annotation-pipeline:Reading centroids segment 163 from metabolomics/tmp/centr_segments/centr_segm_0163.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 199-207
# DEBUG:annotation-pipeline:Saving 108 images
# DEBUG:annotation-pipeline:Segment 163 finished
# DEBUG:annotation-pipeline:Reading centroids segment 164 from metabolomics/tmp/centr_segments/centr_segm_0164.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 199-209
# DEBUG:annotation-pipeline:Saving 247 images
# DEBUG:annotation-pipeline:Segment 164 finished
# DEBUG:annotation-pipeline:Reading centroids segment 165 from metabolomics/tmp/centr_segments/centr_segm_0165.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 201-209
# DEBUG:annotation-pipeline:Saving 91 images
# DEBUG:annotation-pipeline:Segment 165 finished
# DEBUG:annotation-pipeline:Reading centroids segment 166 from metabolomics/tmp/centr_segments/centr_segm_0166.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 201-210
# DEBUG:annotation-pipeline:Saving 93 images
# DEBUG:annotation-pipeline:Segment 166 finished
# DEBUG:annotation-pipeline:Reading centroids segment 167 from metabolomics/tmp/centr_segments/centr_segm_0167.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 202-211
# DEBUG:annotation-pipeline:Saving 155 images
# DEBUG:annotation-pipeline:Segment 167 finished
# DEBUG:annotation-pipeline:Reading centroids segment 168 from metabolomics/tmp/centr_segments/centr_segm_0168.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 203-212
# DEBUG:annotation-pipeline:Saving 94 images
# DEBUG:annotation-pipeline:Segment 168 finished
# DEBUG:annotation-pipeline:Reading centroids segment 169 from metabolomics/tmp/centr_segments/centr_segm_0169.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 203-212
# DEBUG:annotation-pipeline:Saving 125 images
# DEBUG:annotation-pipeline:Segment 169 finished
# DEBUG:annotation-pipeline:Reading centroids segment 170 from metabolomics/tmp/centr_segments/centr_segm_0170.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 204-213
# DEBUG:annotation-pipeline:Saving 22 images
# DEBUG:annotation-pipeline:Segment 170 finished
# DEBUG:annotation-pipeline:Reading centroids segment 171 from metabolomics/tmp/centr_segments/centr_segm_0171.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 205-214
# DEBUG:annotation-pipeline:Saving 179 images
# DEBUG:annotation-pipeline:Segment 171 finished
# DEBUG:annotation-pipeline:Reading centroids segment 172 from metabolomics/tmp/centr_segments/centr_segm_0172.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 205-214
# DEBUG:annotation-pipeline:Saving 206 images
# DEBUG:annotation-pipeline:Segment 172 finished
# DEBUG:annotation-pipeline:Reading centroids segment 173 from metabolomics/tmp/centr_segments/centr_segm_0173.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 207-214
# DEBUG:annotation-pipeline:Saving 160 images
# DEBUG:annotation-pipeline:Segment 173 finished
# DEBUG:annotation-pipeline:Reading centroids segment 174 from metabolomics/tmp/centr_segments/centr_segm_0174.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 207-215
# DEBUG:annotation-pipeline:Saving 84 images
# DEBUG:annotation-pipeline:Segment 174 finished
# DEBUG:annotation-pipeline:Reading centroids segment 175 from metabolomics/tmp/centr_segments/centr_segm_0175.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 209-216
# DEBUG:annotation-pipeline:Saving 196 images
# DEBUG:annotation-pipeline:Segment 175 finished
# DEBUG:annotation-pipeline:Reading centroids segment 176 from metabolomics/tmp/centr_segments/centr_segm_0176.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 210-217
# DEBUG:annotation-pipeline:Saving 101 images
# DEBUG:annotation-pipeline:Segment 176 finished
# DEBUG:annotation-pipeline:Reading centroids segment 177 from metabolomics/tmp/centr_segments/centr_segm_0177.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 211-217
# DEBUG:annotation-pipeline:Saving 45 images
# DEBUG:annotation-pipeline:Segment 177 finished
# DEBUG:annotation-pipeline:Reading centroids segment 178 from metabolomics/tmp/centr_segments/centr_segm_0178.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 211-217
# DEBUG:annotation-pipeline:Saving 65 images
# DEBUG:annotation-pipeline:Segment 178 finished
# DEBUG:annotation-pipeline:Reading centroids segment 179 from metabolomics/tmp/centr_segments/centr_segm_0179.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 212-218
# DEBUG:annotation-pipeline:Saving 110 images
# DEBUG:annotation-pipeline:Segment 179 finished
# DEBUG:annotation-pipeline:Reading centroids segment 180 from metabolomics/tmp/centr_segments/centr_segm_0180.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 213-219
# DEBUG:annotation-pipeline:Saving 222 images
# DEBUG:annotation-pipeline:Segment 180 finished
# ...
# DEBUG:annotation-pipeline:Reading dataset segments 268-271
# DEBUG:annotation-pipeline:Saving 35 images
# DEBUG:annotation-pipeline:Segment 309 finished
# DEBUG:annotation-pipeline:Reading centroids segment 310 from metabolomics/tmp/centr_segments/centr_segm_0310.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 268-271
# DEBUG:annotation-pipeline:Saving 38 images
# DEBUG:annotation-pipeline:Segment 310 finished
# DEBUG:annotation-pipeline:Reading centroids segment 311 from metabolomics/tmp/centr_segments/centr_segm_0311.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 268-272
# DEBUG:annotation-pipeline:Saving 107 images
# DEBUG:annotation-pipeline:Segment 311 finished
# DEBUG:annotation-pipeline:Reading centroids segment 312 from metabolomics/tmp/centr_segments/centr_segm_0312.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 269-272
# DEBUG:annotation-pipeline:Saving 36 images
# DEBUG:annotation-pipeline:Segment 312 finished
# DEBUG:annotation-pipeline:Reading centroids segment 313 from metabolomics/tmp/centr_segments/centr_segm_0313.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 269-272
# DEBUG:annotation-pipeline:Saving 172 images
# DEBUG:annotation-pipeline:Segment 313 finished
# DEBUG:annotation-pipeline:Reading centroids segment 314 from metabolomics/tmp/centr_segments/centr_segm_0314.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 270-273
# DEBUG:annotation-pipeline:Saving 9 images
# DEBUG:annotation-pipeline:Segment 314 finished
# DEBUG:annotation-pipeline:Reading centroids segment 315 from metabolomics/tmp/centr_segments/centr_segm_0315.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 270-273
# DEBUG:annotation-pipeline:Saving 37 images
# DEBUG:annotation-pipeline:Segment 315 finished
# DEBUG:annotation-pipeline:Reading centroids segment 316 from metabolomics/tmp/centr_segments/centr_segm_0316.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 270-273
# DEBUG:annotation-pipeline:Saving 103 images
# DEBUG:annotation-pipeline:Segment 316 finished
# DEBUG:annotation-pipeline:Reading centroids segment 317 from metabolomics/tmp/centr_segments/centr_segm_0317.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 270-273
# DEBUG:annotation-pipeline:Saving 12 images
# DEBUG:annotation-pipeline:Segment 317 finished
# DEBUG:annotation-pipeline:Reading centroids segment 318 from metabolomics/tmp/centr_segments/centr_segm_0318.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 270-273
# DEBUG:annotation-pipeline:Saving 26 images
# DEBUG:annotation-pipeline:Segment 318 finished
# DEBUG:annotation-pipeline:Reading centroids segment 319 from metabolomics/tmp/centr_segments/centr_segm_0319.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 271-274
# DEBUG:annotation-pipeline:Saving 122 images
# DEBUG:annotation-pipeline:Segment 319 finished
# DEBUG:annotation-pipeline:Reading centroids segment 320 from metabolomics/tmp/centr_segments/centr_segm_0320.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 271-274
# DEBUG:annotation-pipeline:Saving 48 images
# DEBUG:annotation-pipeline:Segment 320 finished
# DEBUG:annotation-pipeline:Reading centroids segment 321 from metabolomics/tmp/centr_segments/centr_segm_0321.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 272-274
# DEBUG:annotation-pipeline:Saving 0 images
# DEBUG:annotation-pipeline:Segment 321 finished
# DEBUG:annotation-pipeline:Reading centroids segment 322 from metabolomics/tmp/centr_segments/centr_segm_0322.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 272-274
# DEBUG:annotation-pipeline:Saving 154 images
# DEBUG:annotation-pipeline:Segment 322 finished
# DEBUG:annotation-pipeline:Reading centroids segment 323 from metabolomics/tmp/centr_segments/centr_segm_0323.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 272-275
# DEBUG:annotation-pipeline:Saving 62 images
# DEBUG:annotation-pipeline:Segment 323 finished
# DEBUG:annotation-pipeline:Reading centroids segment 324 from metabolomics/tmp/centr_segments/centr_segm_0324.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 272-275
# DEBUG:annotation-pipeline:Saving 51 images
# DEBUG:annotation-pipeline:Segment 324 finished
# DEBUG:annotation-pipeline:Reading centroids segment 325 from metabolomics/tmp/centr_segments/centr_segm_0325.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 273-275
# DEBUG:annotation-pipeline:Saving 101 images
# DEBUG:annotation-pipeline:Segment 325 finished
# DEBUG:annotation-pipeline:Reading centroids segment 326 from metabolomics/tmp/centr_segments/centr_segm_0326.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 273-276
# DEBUG:annotation-pipeline:Saving 96 images
# DEBUG:annotation-pipeline:Segment 326 finished
# DEBUG:annotation-pipeline:Reading centroids segment 327 from metabolomics/tmp/centr_segments/centr_segm_0327.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 273-276
# DEBUG:annotation-pipeline:Saving 85 images
# DEBUG:annotation-pipeline:Segment 327 finished
# DEBUG:annotation-pipeline:Reading centroids segment 328 from metabolomics/tmp/centr_segments/centr_segm_0328.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 273-276
# DEBUG:annotation-pipeline:Saving 30 images
# DEBUG:annotation-pipeline:Segment 328 finished
# DEBUG:annotation-pipeline:Reading centroids segment 329 from metabolomics/tmp/centr_segments/centr_segm_0329.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 273-276
# DEBUG:annotation-pipeline:Saving 21 images
# DEBUG:annotation-pipeline:Segment 329 finished
# DEBUG:annotation-pipeline:Reading centroids segment 330 from metabolomics/tmp/centr_segments/centr_segm_0330.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 274-276
# DEBUG:annotation-pipeline:Saving 133 images
# DEBUG:annotation-pipeline:Segment 330 finished
# DEBUG:annotation-pipeline:Reading centroids segment 331 from metabolomics/tmp/centr_segments/centr_segm_0331.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 274-276
# DEBUG:annotation-pipeline:Saving 0 images
# DEBUG:annotation-pipeline:Segment 331 finished
# DEBUG:annotation-pipeline:Reading centroids segment 332 from metabolomics/tmp/centr_segments/centr_segm_0332.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 274-277
# DEBUG:annotation-pipeline:Saving 52 images
# DEBUG:annotation-pipeline:Segment 332 finished
# DEBUG:annotation-pipeline:Reading centroids segment 333 from metabolomics/tmp/centr_segments/centr_segm_0333.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 274-277
# DEBUG:annotation-pipeline:Saving 132 images
# DEBUG:annotation-pipeline:Segment 333 finished
# DEBUG:annotation-pipeline:Reading centroids segment 334 from metabolomics/tmp/centr_segments/centr_segm_0334.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 275-277
# DEBUG:annotation-pipeline:Saving 65 images
# DEBUG:annotation-pipeline:Segment 334 finished
# DEBUG:annotation-pipeline:Reading centroids segment 335 from metabolomics/tmp/centr_segments/centr_segm_0335.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 275-277
# DEBUG:annotation-pipeline:Saving 0 images
# DEBUG:annotation-pipeline:Segment 335 finished
# DEBUG:annotation-pipeline:Reading centroids segment 336 from metabolomics/tmp/centr_segments/centr_segm_0336.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 275-277
# DEBUG:annotation-pipeline:Saving 161 images
# DEBUG:annotation-pipeline:Segment 336 finished
# DEBUG:annotation-pipeline:Reading centroids segment 337 from metabolomics/tmp/centr_segments/centr_segm_0337.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 276-277
# DEBUG:annotation-pipeline:Saving 44 images
# DEBUG:annotation-pipeline:Segment 337 finished
# DEBUG:annotation-pipeline:Reading centroids segment 338 from metabolomics/tmp/centr_segments/centr_segm_0338.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 276-277
# DEBUG:annotation-pipeline:Saving 65 images
# DEBUG:annotation-pipeline:Segment 338 finished
# DEBUG:annotation-pipeline:Reading centroids segment 339 from metabolomics/tmp/centr_segments/centr_segm_0339.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 276-278
# DEBUG:annotation-pipeline:Saving 68 images
# DEBUG:annotation-pipeline:Segment 339 finished
# DEBUG:annotation-pipeline:Reading centroids segment 340 from metabolomics/tmp/centr_segments/centr_segm_0340.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 276-278
# DEBUG:annotation-pipeline:Saving 64 images
# DEBUG:annotation-pipeline:Segment 340 finished
# DEBUG:annotation-pipeline:Reading centroids segment 341 from metabolomics/tmp/centr_segments/centr_segm_0341.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 276-278
# DEBUG:annotation-pipeline:Saving 173 images
# DEBUG:annotation-pipeline:Segment 341 finished
# DEBUG:annotation-pipeline:Reading centroids segment 342 from metabolomics/tmp/centr_segments/centr_segm_0342.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-278
# DEBUG:annotation-pipeline:Saving 4 images
# DEBUG:annotation-pipeline:Segment 342 finished
# DEBUG:annotation-pipeline:Reading centroids segment 343 from metabolomics/tmp/centr_segments/centr_segm_0343.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-279
# DEBUG:annotation-pipeline:Saving 51 images
# DEBUG:annotation-pipeline:Segment 343 finished
# DEBUG:annotation-pipeline:Reading centroids segment 344 from metabolomics/tmp/centr_segments/centr_segm_0344.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-279
# DEBUG:annotation-pipeline:Saving 112 images
# DEBUG:annotation-pipeline:Segment 344 finished
# DEBUG:annotation-pipeline:Reading centroids segment 345 from metabolomics/tmp/centr_segments/centr_segm_0345.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-279
# DEBUG:annotation-pipeline:Saving 43 images
# DEBUG:annotation-pipeline:Segment 345 finished
# DEBUG:annotation-pipeline:Reading centroids segment 346 from metabolomics/tmp/centr_segments/centr_segm_0346.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-279
# DEBUG:annotation-pipeline:Saving 70 images
# DEBUG:annotation-pipeline:Segment 346 finished
# DEBUG:annotation-pipeline:Reading centroids segment 347 from metabolomics/tmp/centr_segments/centr_segm_0347.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-279
# DEBUG:annotation-pipeline:Saving 63 images
# DEBUG:annotation-pipeline:Segment 347 finished
# DEBUG:annotation-pipeline:Reading centroids segment 348 from metabolomics/tmp/centr_segments/centr_segm_0348.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-280
# DEBUG:annotation-pipeline:Saving 41 images
# DEBUG:annotation-pipeline:Segment 348 finished
# DEBUG:annotation-pipeline:Reading centroids segment 349 from metabolomics/tmp/centr_segments/centr_segm_0349.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 277-280
# DEBUG:annotation-pipeline:Saving 52 images
# DEBUG:annotation-pipeline:Segment 349 finished
# DEBUG:annotation-pipeline:Reading centroids segment 350 from metabolomics/tmp/centr_segments/centr_segm_0350.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 278-280
# DEBUG:annotation-pipeline:Saving 67 images
# DEBUG:annotation-pipeline:Segment 350 finished
# DEBUG:annotation-pipeline:Reading centroids segment 351 from metabolomics/tmp/centr_segments/centr_segm_0351.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 278-280
# DEBUG:annotation-pipeline:Saving 16 images
# DEBUG:annotation-pipeline:Segment 351 finished
# DEBUG:annotation-pipeline:Reading centroids segment 352 from metabolomics/tmp/centr_segments/centr_segm_0352.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 278-281
# DEBUG:annotation-pipeline:Saving 103 images
# DEBUG:annotation-pipeline:Segment 352 finished
# DEBUG:annotation-pipeline:Reading centroids segment 353 from metabolomics/tmp/centr_segments/centr_segm_0353.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 7 images
# DEBUG:annotation-pipeline:Segment 353 finished
# DEBUG:annotation-pipeline:Reading centroids segment 354 from metabolomics/tmp/centr_segments/centr_segm_0354.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 26 images
# DEBUG:annotation-pipeline:Segment 354 finished
# DEBUG:annotation-pipeline:Reading centroids segment 355 from metabolomics/tmp/centr_segments/centr_segm_0355.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 94 images
# DEBUG:annotation-pipeline:Segment 355 finished
# DEBUG:annotation-pipeline:Reading centroids segment 356 from metabolomics/tmp/centr_segments/centr_segm_0356.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 71 images
# DEBUG:annotation-pipeline:Segment 356 finished
# DEBUG:annotation-pipeline:Reading centroids segment 357 from metabolomics/tmp/centr_segments/centr_segm_0357.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 18 images
# DEBUG:annotation-pipeline:Segment 357 finished
# DEBUG:annotation-pipeline:Reading centroids segment 358 from metabolomics/tmp/centr_segments/centr_segm_0358.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 279-281
# DEBUG:annotation-pipeline:Saving 99 images
# DEBUG:annotation-pipeline:Segment 358 finished
# DEBUG:annotation-pipeline:Reading centroids segment 359 from metabolomics/tmp/centr_segments/centr_segm_0359.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 280-281
# DEBUG:annotation-pipeline:Saving 36 images
# DEBUG:annotation-pipeline:Segment 359 finished
# DEBUG:annotation-pipeline:Reading centroids segment 360 from metabolomics/tmp/centr_segments/centr_segm_0360.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 280-281
# DEBUG:annotation-pipeline:Saving 136 images
# DEBUG:annotation-pipeline:Segment 360 finished
# DEBUG:annotation-pipeline:Reading centroids segment 361 from metabolomics/tmp/centr_segments/centr_segm_0361.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 280-281
# DEBUG:annotation-pipeline:Saving 35 images
# DEBUG:annotation-pipeline:Segment 361 finished
# DEBUG:annotation-pipeline:Reading centroids segment 362 from metabolomics/tmp/centr_segments/centr_segm_0362.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 280-281
# DEBUG:annotation-pipeline:Saving 46 images
# DEBUG:annotation-pipeline:Segment 362 finished
# DEBUG:annotation-pipeline:Reading centroids segment 363 from metabolomics/tmp/centr_segments/centr_segm_0363.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 108 images
# DEBUG:annotation-pipeline:Segment 363 finished
# DEBUG:annotation-pipeline:Reading centroids segment 364 from metabolomics/tmp/centr_segments/centr_segm_0364.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 51 images
# DEBUG:annotation-pipeline:Segment 364 finished
# DEBUG:annotation-pipeline:Reading centroids segment 365 from metabolomics/tmp/centr_segments/centr_segm_0365.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 24 images
# DEBUG:annotation-pipeline:Segment 365 finished
# DEBUG:annotation-pipeline:Reading centroids segment 366 from metabolomics/tmp/centr_segments/centr_segm_0366.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 49 images
# DEBUG:annotation-pipeline:Segment 366 finished
# DEBUG:annotation-pipeline:Reading centroids segment 367 from metabolomics/tmp/centr_segments/centr_segm_0367.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 33 images
# DEBUG:annotation-pipeline:Segment 367 finished
# DEBUG:annotation-pipeline:Reading centroids segment 368 from metabolomics/tmp/centr_segments/centr_segm_0368.msgpack
# DEBUG:annotation-pipeline:Reading dataset segments 281-281
# DEBUG:annotation-pipeline:Saving 0 images
# DEBUG:annotation-pipeline:Segment 368 finished
# INFO:annotation-pipeline:Metrics calculated: 37751
# CPU times: user 17min 29s, sys: 11.6 s, total: 17min 41s
# Wall time: 17min 41s

# %%
formula_metrics_df.shape
# Out:
# (37751, 7)

# %%
formula_metrics_df.head()
# Out:
#               chaos   spatial  spectral       msm  \
# formula_i
# 1136298    0.989467  0.005032  0.993460  0.004946
# 1136874    0.994783  0.005596  0.981136  0.005462
# 1467671    0.998180  0.055214  0.990467  0.054588
# 1470137    0.995650  0.000279  0.990636  0.000275
# 1471562    0.995417  0.024108  0.990455  0.023768
#
#                                               total_iso_ints  min_iso_ints  \
# formula_i
# 1136298    [5469792.814208984, 8950.914428710938, 49009.3...  [0, 0, 0, 0]
# 1136874    [40829342.67486572, 10844.889709472656, 24336....  [0, 0, 0, 0]
# 1467671    [53361335.24902344, 6351.7821044921875, 48062....  [0, 0, 0, 0]
# 1470137    [14824101.560913086, 14878.147338867188, 56461...  [0, 0, 0, 0]
# 1471562    [28735164.747802734, 1051.5220947265625, 21886...  [0, 0, 0, 0]
#
#                                                 max_iso_ints
# formula_i
# 1136298    [9209.248046875, 1063.4140625, 2859.4926757812...
# 1136874    [60895.3046875, 1248.24755859375, 1485.7324218...
# 1467671    [25295.4765625, 1144.1231689453125, 1721.48474...
# 1470137    [7332.09912109375, 1066.228759765625, 2174.179...
# 1471562    [9924.072265625, 1051.5220947265625, 1265.2122...

# %% [markdown]
# # Clean Temp Data

# %%
from annotation_pipeline.dataset_segmentation import clean_segments

# %%
# %%time
clean_segments(config, input_data)
